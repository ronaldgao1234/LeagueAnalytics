# %% [markdown]
# ## LCS Player Analysis
#
# ### Stats to look into for every player
# - This split's VODS:
#     - Their positioning tendencies
#     - Thier warding patterns
#     - Rewatch TL Kay's videos again to see what to get
#     - Thier picks
#     - Rewatch some analysis videos
#
# - Overall
#     - Stats that he provided vs other players (worlds, lcs, etc.)
#         - Averages for everything + graphs

# %% [markdown]
# Kays comment:
#
# ```
# First thing I would do is create a portfolio of work for a specific team. This can include, but not limited to, build calculations, databases, international regional reports, in depth jungle analysis, scouting reports, etc
# ```

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Importing data

# %%
spring2020 = pd.read_excel('./data/2020/2020-spring-match-data.xlsx')  # February 17

spring2019 = pd.read_excel('./data/2019/2019-spring-match-data.xlsx')
summer2019 = pd.read_excel('./data/2019/2019-summer-match-data.xlsx')
worlds2019 = pd.read_excel('./data/2019/2019-worlds-match-data.xlsx')

spring2018 = pd.read_excel('./data/2018/2018-spring-match-data.xlsx')
summer2018 = pd.read_excel('./data/2018/2018-summer-match-data.xlsx')
worlds2018 = pd.read_excel('./data/2018/2018-worlds-match-data.xlsx')

# %%
# Aggregate into one giant file
data = spring2020
excel_files = [spring2019, summer2019, worlds2019, spring2018, summer2018, worlds2018]
for e in excel_files:
    data = data.append(e,sort=False)

# %%
len(data)
# Out:
# 62892

# %%
### Replace NALCS and EULCS with LCS/LEC
data = data.replace(['NALCS', 'EULCS'], ['LCS', 'LEC'])

# %%
# Take out Worlds and MSI data
overall = data[~data.league.isin(['WC', 'MSI'])]

# %% [markdown]
# ### Overall Average Player Stats
#
# The data will exclude worlds and msi data
#
# - Average K,D,A
#     - By Player + Result + Patch
#     - By Region + Result + Patch
#     - By Position + Result + Patch
#     - By Champion + Result + Patch

# %%
mean_num_games_per_player = int(overall.groupby(['player']).count().gameid.mean())
print(f'Avg Number of games per player {mean_num_games_per_player}')
# Out:
# Avg Number of games per player 65

# %%
# Add kda column
overall['kda'] = (overall['k'] + overall['a']) / overall['d'].replace([0,1])
# Out:
# D:\Users\aznro\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# base_cols = ['player', 'league', 'patchno', 'result', 'position', 'champion']
rp = ['result', 'patchno','k','d','a', 'kda']
player_rp = overall[rp+['player']]
player_rp['big_patch'] = player_rp['patchno'].astype(str).str.split('.', expand=True)[0]
player_rp.drop('patchno',axis=1,inplace=True)

# %%
mean_playrp = player_rp.groupby(['result', 'big_patch', 'player']).mean().reset_index()

# %%
mean_playrp[mean_playrp.player == "ADD"]
# Out:
#       result big_patch player         k         d         a       kda
# 301        0         8    ADD  0.943396  2.867925  1.962264  0.913425
# 907        0         9    ADD  1.621622  3.783784  3.972973  1.622844
# 1717       1         8    ADD  1.869565  1.434783  7.565217  2.647769
# 2303       1         9    ADD  3.288889  1.755556  6.911111  3.755432

# %%
mean_playrp

# %%
def getOverallStats(player_name):

# %%
data.columns
# Out:
# Index(['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno',
#        'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1',
#        'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a',
#        'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas',
#        'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd',
#        'fdtime', 'teamdragkills', 'oppdragkills', 'elementals',
#        'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes',
#        'airdrakes', 'elders', 'oppelders', 'heraldkills', 'oppheraldkills',
#        'ft', 'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills',
#        'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills',
#        'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare',
#        'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm',
#        'visionwards', 'visionwardbuys', 'visiblewardclearrate',
#        'invisiblewardclearrate', 'totalgold', 'earnedgpm', 'goldspent', 'gspd',
#        'minionkills', 'monsterkills', 'monsterkillsownjungle',
#        'monsterkillsenemyjungle', 'cspm', 'goldat10', 'oppgoldat10', 'gdat10',
#        'goldat15', 'oppgoldat15', 'gdat15', 'xpat10', 'oppxpat10', 'xpdat10',
#        'csat10', 'oppcsat10', 'csdat10', 'csat15', 'oppcsat15', 'csdat15',
#        'herald', 'heraldtime'],
#       dtype='object')

# %% [markdown]
# ### Stats that I will look into for every player
#
# - Players avg kda over past two years vs his kda right now as well as his k,d,a separately

# %% [markdown]
# ### Team Liquid

# %% [markdown]
# #### Doublelift

# %%
doublelift = overall[overaell.player == 'Doublelift']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2c86b8f2a07d> in <module>()
# ----> 1 doublelift = overall[overaell.player == 'Doublelift']
#
# NameError: name 'overaell' is not defined

# %%
doublelift.league.value_counts()
# Out:
# LCS      62
# NALCS    55
# MSI      31
# WC       12
# Name: league, dtype: int64

# %%
doublelift.drop(['gameid', 'league', 'split', 'date',], axis=1, inplace=True)
# Out:
#            gameid                                                url league  \
# 548       1270555  http://matchhistory.na.leagueoflegends.com/en/...    LCS
# 735       1271104  http://matchhistory.na.leagueoflegends.com/en/...    LCS
# 920       1291426  http://matchhistory.na.leagueoflegends.com/en/...    LCS
# 951       1291748  https://matchhistory.na.leagueoflegends.com/en...    LCS
# 1520      1304374  https://matchhistory.na.leagueoflegends.com/en...    LCS
# 1671      1295383  https://matchhistory.na.leagueoflegends.com/en...    LCS
# 2175      1281254  https://matchhistory.na.leagueoflegends.com/en...    LCS
# 2300      1281549  http://matchhistory.na.leagueoflegends.com/en/...    LCS
# 1083       992625  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 1419       992872  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 2936      1061592  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 2991      1051827  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 3164      1053221  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 3231      1053417  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 3716      1012155  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 3783      1012483  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 4827      1014822  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 4923      1015214  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 5703      1021654  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 5751      1031841  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 7095      1023897  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 7148      1024218  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 8031      1071762  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 8619      1082183  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 8660      1074172  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 8739      1074525  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 10947     1033056  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 10959     1033067  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 10971     1033073  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# 11451     1024049  https://matchhistory.euw.leagueoflegends.com/e...    LCS
# ...           ...                                                ...    ...
# 831    1002620082  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 1904   1002650020  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 2115   1002650069  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 3855   1002650117  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 3932   1002650168  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 5199   1002670217  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 5240   1002670235  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 6320   1002660286  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 6387   1002660337  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 8288   1002690023  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 8331   1002690057  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 10107  1002680095  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 10167  1002680137  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 11564  1002710038  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 11619  1002710079  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 12128  1002710167  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 12236  1002710243  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 14408  1002720106  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 14420  1002720116  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 14427  1002720117  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 14439  1002720118  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 14919  1002750055  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 14931  1002750058  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 14943  1002750060  https://matchhistory.na.leagueoflegends.com/en...  NALCS
# 512    1002490120  https://matchhistory.na.leagueoflegends.com/en...     WC
# 663    1002490264  https://matchhistory.na.leagueoflegends.com/en...     WC
# 771    1002490365  https://matchhistory.na.leagueoflegends.com/en...     WC
# 963    1002490513  https://matchhistory.na.leagueoflegends.com/en...     WC
# 992    1002490532  https://matchhistory.na.leagueoflegends.com/en...     WC
# 1016   1002490548  https://matchhistory.na.leagueoflegends.com/en...     WC
#
#          split     date week game  patchno  playerid  side     ...      \
# 548     2020-1  43855.7    1    1    10.01         9   Red     ...
# 735     2020-1  43857.9    1    3    10.01         4  Blue     ...
# 920     2020-1  43862.7    2    1    10.02         9   Red     ...
# 951     2020-1  43863.6    2    2    10.02         4  Blue     ...
# 1520    2020-1  43869.7    3    1    10.02         9   Red     ...
# 1671    2020-1  43871.8    3    3    10.02         4  Blue     ...
# 2175    2020-1  43876.7    4    1    10.03         4  Blue     ...
# 2300    2020-1  43877.7    4    2    10.03         9   Red     ...
# 1083    2019-1  43491.7    1    1     9.01         4  Blue     ...
# 1419    2019-1  43492.7    1    2     9.01         4  Blue     ...
# 2936    2019-1  43498.8    2    1     9.02         9   Red     ...
# 2991    2019-1  43499.7    2    2     9.02         4  Blue     ...
# 3164    2019-1  43505.8    3    1     9.02         9   Red     ...
# 3231    2019-1  43506.7    3    2     9.02         4  Blue     ...
# 3716    2019-1  43512.7    4    1     9.03         9   Red     ...
# 3783    2019-1  43513.7    4    2     9.03         4  Blue     ...
# 4827    2019-1  43519.7    5    1     9.03         4  Blue     ...
# 4923    2019-1  43520.8    5    2     9.03         4  Blue     ...
# 5703    2019-1  43526.9    6    1     9.04         4  Blue     ...
# 5751    2019-1  43527.7    6    2     9.04         4  Blue     ...
# 7095    2019-1  43533.7    7    1     9.04         4  Blue     ...
# 7148    2019-1  43534.6    7    2     9.04         9   Red     ...
# 8031    2019-1  43540.7    8    1     9.05         4  Blue     ...
# 8619    2019-1  43541.7    8    2     9.05         4  Blue     ...
# 8660    2019-1  43547.7    9    1     9.05         9   Red     ...
# 8739    2019-1  43548.7    9    2     9.05         4  Blue     ...
# 10947  2019-1P  43562.6   SF    1     9.06         4  Blue     ...
# 10959  2019-1P  43562.6   SF    2     9.06         4  Blue     ...
# 10971  2019-1P  43562.6   SF    3     9.06         4  Blue     ...
# 11451  2019-1P  43568.6    F    1     9.06         4  Blue     ...
# ...        ...      ...  ...  ...      ...       ...   ...     ...
# 831     2018-2  43268.6    1    2     8.11         4  Blue     ...
# 1904    2018-2  43274.6    2    1     8.12         9   Red     ...
# 2115    2018-2  43275.7    2    2     8.12         4  Blue     ...
# 3855    2018-2  43281.7    3    1     8.12         4  Blue     ...
# 3932    2018-2  43282.7    3    2     8.12         9   Red     ...
# 5199    2018-2  43295.8    4    1     8.13         4  Blue     ...
# 5240    2018-2  43296.6    4    2     8.13         9   Red     ...
# 6320    2018-2  43302.7    5    1     8.13         9   Red     ...
# 6387    2018-2  43303.7    5    2     8.13         4  Blue     ...
# 8288    2018-2  43309.8    6    1     8.14         9   Red     ...
# 8331    2018-2  43310.7    6    2     8.14         4  Blue     ...
# 10107   2018-2  43316.7    7    1     8.14         4  Blue     ...
# 10167   2018-2  43317.6    7    2     8.14         4  Blue     ...
# 11564   2018-2  43323.8    8    1     8.15         9   Red     ...
# 11619   2018-2  43324.7    8    2     8.15         4  Blue     ...
# 12128   2018-2  43330.7    9    1     8.15         9   Red     ...
# 12236   2018-2  43331.7    9    2     8.15         9   Red     ...
# 14408  2018-2p  43345.6   SF    1     8.16         9   Red     ...
# 14420  2018-2p  43345.6   SF    2     8.16         9   Red     ...
# 14427  2018-2p  43345.7   SF    3     8.16         4  Blue     ...
# 14439  2018-2p  43345.7   SF    4     8.16         4  Blue     ...
# 14919  2018-2p  43352.7    F    1     8.16         4  Blue     ...
# 14931  2018-2p  43352.7    F    2     8.16         4  Blue     ...
# 14943  2018-2p  43352.7    F    3     8.16         4  Blue     ...
# 512     2018-W  43383.1    G    1     8.19         9   Red     ...
# 663     2018-W  43385.1    G    3     8.19         4  Blue     ...
# 771     2018-W  43386.3    G    4     8.19         4  Blue     ...
# 963     2018-W  43389.1    G    7     8.19         4  Blue     ...
# 992     2018-W  43389.2    G    7     8.19         9   Red     ...
# 1016    2018-W  43389.3    G    7     8.19         9   Red     ...
#
#       oppxpat10 xpdat10 csat10 oppcsat10 csdat10 csat15 oppcsat15 csdat15  \
# 548      3524.0  -391.0   86.0      95.0    -9.0  127.0     140.0   -13.0
# 735      2938.0  -179.0   81.0      73.0     8.0  135.0     119.0    16.0
# 920      3137.0   -87.0   87.0      90.0    -3.0  142.0     126.0    16.0
# 951      3017.0   724.0   94.0      77.0    17.0  145.0     132.0    13.0
# 1520     3075.0   599.0   88.0      84.0     4.0  146.0     146.0     0.0
# 1671     3481.0  -516.0   73.0      97.0   -24.0  120.0     149.0   -29.0
# 2175     3002.0   417.0  101.0      81.0    20.0  148.0     136.0    12.0
# 2300     3053.0   195.0   91.0      72.0    19.0  149.0     109.0    40.0
# 1083     3260.0   413.0   92.0      80.0    12.0  147.0     122.0    25.0
# 1419     3162.0   163.0   91.0      87.0     4.0  145.0     148.0    -3.0
# 2936     3146.0   -24.0   89.0      73.0    16.0  146.0     117.0    29.0
# 2991     2856.0   416.0   86.0      78.0     8.0  137.0     130.0     7.0
# 3164     2857.0   410.0   85.0      68.0    17.0  142.0     129.0    13.0
# 3231     3577.0  -351.0   90.0      93.0    -3.0  153.0     150.0     3.0
# 3716     3197.0    94.0   70.0      97.0   -27.0  134.0     151.0   -17.0
# 3783     3306.0   272.0   87.0      90.0    -3.0  145.0     141.0     4.0
# 4827     3262.0    25.0  103.0      97.0     6.0  168.0     155.0    13.0
# 4923     3139.0   404.0  105.0      95.0    10.0  152.0     139.0    13.0
# 5703     3421.0   119.0   97.0      89.0     8.0  154.0     130.0    24.0
# 5751     3333.0    59.0   98.0      91.0     7.0  154.0     145.0     9.0
# 7095     3250.0    59.0   98.0      89.0     9.0  152.0     144.0     8.0
# 7148     3112.0   271.0   96.0      89.0     7.0  147.0     151.0    -4.0
# 8031     3326.0  -417.0   67.0      87.0   -20.0  124.0     139.0   -15.0
# 8619     3461.0  -239.0   93.0      92.0     1.0  137.0     135.0     2.0
# 8660     3199.0  -257.0   75.0      94.0   -19.0  128.0     144.0   -16.0
# 8739     3067.0    27.0   93.0      87.0     6.0  158.0     138.0    20.0
# 10947    3225.0   -69.0   34.0      83.0   -49.0   82.0     143.0   -61.0
# 10959    3426.0   -21.0   97.0      89.0     8.0  164.0     152.0    12.0
# 10971    3303.0   119.0  102.0      98.0     4.0  158.0     149.0     9.0
# 11451    3287.0   155.0   94.0     100.0    -6.0  138.0     149.0   -11.0
# ...         ...     ...    ...       ...     ...    ...       ...     ...
# 831      3515.0    -9.0   81.0      90.0    -9.0  145.0     151.0    -6.0
# 1904     3271.0  -322.0   83.0      96.0   -13.0  135.0     142.0    -7.0
# 2115     3594.0   130.0  105.0      91.0    14.0  172.0     150.0    22.0
# 3855     2934.0   565.0   90.0      63.0    27.0  138.0      93.0    45.0
# 3932     3236.0   210.0   96.0      89.0     7.0  145.0     147.0    -2.0
# 5199     3233.0   -57.0   93.0      76.0    17.0  146.0     115.0    31.0
# 5240     3346.0    50.0   88.0      97.0    -9.0  134.0     150.0   -16.0
# 6320     3219.0   285.0  100.0      73.0    27.0  147.0     112.0    35.0
# 6387     3259.0   -19.0   90.0      83.0     7.0  154.0     131.0    23.0
# 8288     3445.0    13.0   73.0      82.0    -9.0  126.0     135.0    -9.0
# 8331     3330.0   156.0   99.0      75.0    24.0  158.0     109.0    49.0
# 10107    3026.0   299.0   97.0      88.0     9.0  159.0     139.0    20.0
# 10167    3061.0   217.0   95.0      90.0     5.0  142.0     147.0    -5.0
# 11564    3122.0    69.0   84.0      92.0    -8.0  141.0     144.0    -3.0
# 11619    3097.0   252.0  101.0      89.0    12.0  157.0     149.0     8.0
# 12128    2999.0   259.0   98.0      92.0     6.0  153.0     134.0    19.0
# 12236    2727.0   816.0   92.0      65.0    27.0  151.0     107.0    44.0
# 14408    2781.0   951.0   98.0      82.0    16.0  158.0     134.0    24.0
# 14420    3117.0   289.0   97.0      80.0    17.0  163.0     121.0    42.0
# 14427    2841.0   755.0   94.0      82.0    12.0  158.0     133.0    25.0
# 14439    2883.0   510.0   91.0      73.0    18.0  155.0     122.0    33.0
# 14919    2831.0   280.0   87.0      75.0    12.0  135.0     133.0     2.0
# 14931    3877.0  -784.0   82.0      95.0   -13.0  133.0     136.0    -3.0
# 14943    3560.0    69.0  101.0      88.0    13.0  165.0     148.0    17.0
# 512      3188.0   103.0   78.0      91.0   -13.0  135.0     137.0    -2.0
# 663      3301.0  -145.0   71.0      89.0   -18.0  127.0     156.0   -29.0
# 771      3807.0  -587.0   98.0      88.0    10.0  153.0     132.0    21.0
# 963      3243.0  -207.0   84.0      94.0   -10.0  137.0     146.0    -9.0
# 992      3137.0  -170.0   84.0      86.0    -2.0  157.0     150.0     7.0
# 1016     2917.0   568.0   89.0      78.0    11.0  137.0     131.0     6.0
#
#       herald  heraldtime
# 548      NaN         NaN
# 735      NaN         NaN
# 920      NaN         NaN
# 951      NaN         NaN
# 1520     NaN         NaN
# 1671     NaN         NaN
# 2175     NaN         NaN
# 2300     NaN         NaN
# 1083     0.0         NaN
# 1419     1.0         NaN
# 2936     0.0         NaN
# 2991     1.0         NaN
# 3164     0.0         NaN
# 3231     0.0         NaN
# 3716     0.0         NaN
# 3783     0.0         NaN
# 4827     1.0         NaN
# 4923     1.0         NaN
# 5703     1.0         NaN
# 5751     1.0         NaN
# 7095     1.0         NaN
# 7148     1.0         NaN
# 8031     1.0         NaN
# 8619     1.0         NaN
# 8660     0.0         NaN
# 8739     0.0         NaN
# 10947    1.0         NaN
# 10959    1.0         NaN
# 10971    1.0         NaN
# 11451    1.0         NaN
# ...      ...         ...
# 831      1.0         NaN
# 1904     1.0         NaN
# 2115     1.0         NaN
# 3855     1.0         NaN
# 3932     0.0         NaN
# 5199     0.0         NaN
# 5240     0.0         NaN
# 6320     0.0         NaN
# 6387     0.0         NaN
# 8288     1.0         NaN
# 8331     1.0         NaN
# 10107    1.0         NaN
# 10167    1.0         NaN
# 11564    0.0         NaN
# 11619    0.0         NaN
# 12128    0.0         NaN
# 12236    0.0         NaN
# 14408    0.0         NaN
# 14420    0.0         NaN
# 14427    1.0         NaN
# 14439    1.0         NaN
# 14919    1.0         NaN
# 14931    1.0         NaN
# 14943    1.0         NaN
# 512      0.0         NaN
# 663      NaN         NaN
# 771      1.0         NaN
# 963      0.0         NaN
# 992      0.0         NaN
# 1016     1.0         NaN
#
# [160 rows x 100 columns]
